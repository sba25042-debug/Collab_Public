# %% [markdown]
# <a href="https://colab.research.google.com/github/sba25042-debug/Collab_Public/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
